# %% [markdown]
# # Experiment-4

# %% [markdown]
# Custom Dataset

# %%
import numpy as np
import pandas as pd
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
positive_sentences = [
"I love this product",
"This movie was amazing",
"The service was excellent",
"I am very happy",
"Fantastic experience",
"Great quality",
"Absolutely wonderful",
"I enjoyed it",
"Highly recommended",
"Best purchase",
"Very satisfying",
"This made my day",
"Superb performance",
"I really like it",
"Outstanding work",
"It works perfectly",
"Great support",
"Very impressive",
"Loved it",
"Worth the money"
]

negative_sentences = [
"I hate this product",
"This movie was terrible",
"The service was awful",
"I am very disappointed",
"Worst experience",
"Poor quality",
"Absolutely horrible",
"I regret buying this",
"Not recommended",
"Waste of money",
"Very unsatisfying",
"This ruined my day",
"Bad performance",
"I dislike it",
"Terrible work",
"It does not work",
"Very bad support",
"Not impressive",
"I hated it",
"Totally useless"
]

# %%
data = []

for _ in range(300):
    data.append([random.choice(positive_sentences),"positive"])
    data.append([random.choice(negative_sentences),"negative"])

df = pd.DataFrame(data,columns=["text","sentiment"])

df.head()
# Out:
#                 text sentiment
# 0   I really like it  positive
# 1    Bad performance  negative
# 2    I am very happy  positive
# 3  Very unsatisfying  negative
# 4    Very impressive  positive

# %%
df["sentiment"] = df["sentiment"].map({
    "positive": 1,
    "negative": 0
})

labels = df["sentiment"].values

# %%
tokenizer = Tokenizer(num_words=1000)

tokenizer.fit_on_texts(df["text"])

sequences = tokenizer.texts_to_sequences(df["text"])

X = pad_sequences(sequences, maxlen=10)

y = labels

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42
)

print("Training samples:",X_train.shape)
print("Testing samples:",X_test.shape)
# Out:
# Training samples: (450, 10)
# Testing samples: (150, 10)

# %% [markdown]
# Simple RNN

# %%
rnn_model = Sequential([
    Embedding(4000,32,input_length=10),
    SimpleRNN(128,activation="tanh"),
    Dense(1,activation="sigmoid")
])

rnn_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn = rnn_model.fit(
    X_train,
    y_train,
    epochs=20,
    validation_data=(X_test,y_test)
)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.6244 - loss: 0.6668 - val_accuracy: 0.7133 - val_loss: 0.6080
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7733 - loss: 0.5592 - val_accuracy: 0.9267 - val_loss: 0.4274
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9022 - loss: 0.3367 - val_accuracy: 0.9267 - val_loss: 0.2139
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9200 - loss: 0.1779 - val_accuracy: 0.9333 - val_loss: 0.1253
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9644 - loss: 0.1139 - val_accuracy: 0.9733 - val_loss: 0.0792
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9933 - loss: 0.0712 - val_accuracy: 1.0000 - val_loss: 0.0471
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0401 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0012

# %% [markdown]
# LSTM

# %%
lstm_model = Sequential([
    Embedding(4000,32,input_length=10),
    LSTM(64),
    Dense(1,activation="sigmoid")
])

lstm_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm = lstm_model.fit(
    X_train,
    y_train,
    epochs=20,
    validation_data=(X_test,y_test)
)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.5622 - loss: 0.6907 - val_accuracy: 0.7467 - val_loss: 0.6841
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6267 - loss: 0.6745 - val_accuracy: 0.7200 - val_loss: 0.6592
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8756 - loss: 0.6285 - val_accuracy: 0.9400 - val_loss: 0.5789
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8422 - loss: 0.5246 - val_accuracy: 1.0000 - val_loss: 0.4293
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9222 - loss: 0.3752 - val_accuracy: 1.0000 - val_loss: 0.2711
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9978 - loss: 0.1881 - val_accuracy: 1.0000 - val_loss: 0.0651
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9911 - loss: 0.0599 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0010

# %% [markdown]
# RNN & LSTM Results

# %%
def evaluate_model(model, X_test, y_test, model_name):
    y_pred_prob = model.predict(X_test)
    y_pred = (y_pred_prob > 0.5).astype(int)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"--- {model_name} Performance ---")
    print(f"Accuracy:  {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall:    {recall:.4f}")
    print(f"F1 Score:  {f1:.4f}\n")

    return y_pred

# %%
def predict_samples(model, tokenizer, texts):
    seqs = tokenizer.texts_to_sequences(texts)
    padded = pad_sequences(seqs, maxlen=10)
    preds = model.predict(padded)
    for text, score in zip(texts, preds):
        sentiment = "Positive" if score > 0.5 else "Negative"
        print(f"Text: '{text}' -> Sentiment: {sentiment} ({score[0]:.4f})")
    print()

# %%
sample_texts = [
    "This is a fantastic product",
    "I really hated the service",
    "It was an okay experience"
]

# %%
print("Evaluating Sample Text Predictions:")
print("RNN Model:")
predict_samples(rnn_model, tokenizer, sample_texts)
print("LSTM Model:")
predict_samples(lstm_model, tokenizer, sample_texts)
# Out:
# Evaluating Sample Text Predictions:
# RNN Model:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Text: 'This is a fantastic product' -> Sentiment: Positive (0.9997)
# Text: 'I really hated the service' -> Sentiment: Positive (0.7712)
# Text: 'It was an okay experience' -> Sentiment: Positive (0.9748)
#
# LSTM Model:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Text: 'This is a fantastic product' -> Sentiment: Positive (0.9996)
# Text: 'I really hated the service' -> Sentiment: Negative (0.0112)
# Text: 'It was an okay experience' -> Sentiment: Positive (0.5594)

# %%
print("RNN Model Performance:")
y_pred_rnn = evaluate_model(rnn_model, X_test, y_test, "RNN Model")

print("LSTM Model Performance:")
y_pred_lstm = evaluate_model(lstm_model, X_test, y_test, "LSTM Model")
# Out:
# RNN Model Performance:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# --- RNN Model Performance ---
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1 Score:  1.0000
#
# LSTM Model Performance:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# --- LSTM Model Performance ---
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1 Score:  1.0000

# %% [markdown]
# RNN and LSTM on imdb Dataset

# %%
import kagglehub

path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'imdb-dataset-of-50k-movie-reviews' dataset.
# Path to dataset files: /kaggle/input/imdb-dataset-of-50k-movie-reviews

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer

from sklearn.metrics import accuracy_score, classification_report

# %%
vocab_size = 10000

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training samples: 25000
# Testing samples: 25000

# %%
print("First review (encoded):")
print(X_train[0])

print("\nSentiment label:")
print(y_train[0])
# Out:
# First review (encoded):
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
#
# Sentiment label:
# 1

# %%
max_len = 200

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

print("Shape of training data:", X_train.shape)
print("Shape of testing data:", X_test.shape)
# Out:
# Shape of training data: (25000, 200)
# Shape of testing data: (25000, 200)

# %%
rnn_model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len),
    SimpleRNN(64, activation='tanh'),
    Dense(1, activation='sigmoid')
])

rnn_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn = rnn_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - accuracy: 0.6189 - loss: 0.6294 - val_accuracy: 0.7652 - val_loss: 0.4905
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.8295 - loss: 0.3894 - val_accuracy: 0.8212 - val_loss: 0.4179
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.8989 - loss: 0.2561 - val_accuracy: 0.8204 - val_loss: 0.4350
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.9380 - loss: 0.1671 - val_accuracy: 0.8024 - val_loss: 0.5304
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.9685 - loss: 0.0924 - val_accuracy: 0.7894 - val_loss: 0.6312

# %%
rnn_loss, rnn_acc = rnn_model.evaluate(X_test, y_test)

print("RNN Test Accuracy:", rnn_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7907 - loss: 0.6214
# RNN Test Accuracy: 0.7906799912452698

# %%
lstm_model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

lstm_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

lstm_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm = lstm_model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 50s 150ms/step - accuracy: 0.7550 - loss: 0.4945 - val_accuracy: 0.8258 - val_loss: 0.3929
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 146ms/step - accuracy: 0.8910 - loss: 0.2715 - val_accuracy: 0.8634 - val_loss: 0.3181
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 44s 141ms/step - accuracy: 0.9236 - loss: 0.2038 - val_accuracy: 0.8734 - val_loss: 0.3261
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 45s 143ms/step - accuracy: 0.9467 - loss: 0.1520 - val_accuracy: 0.8706 - val_loss: 0.3334
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 46s 148ms/step - accuracy: 0.9555 - loss: 0.1238 - val_accuracy: 0.8712 - val_loss: 0.3815

# %%
lstm_loss, lstm_acc = lstm_model.evaluate(X_test, y_test)

print("LSTM Test Accuracy:", lstm_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.8572 - loss: 0.4207
# LSTM Test Accuracy: 0.857200026512146

# %%
print("Model Comparison")

print("RNN Accuracy :", rnn_acc)
print("LSTM Accuracy:", lstm_acc)
# Out:
# Model Comparison
# RNN Accuracy : 0.7906799912452698
# LSTM Accuracy: 0.857200026512146
